# %%
# Importación de librerías esenciales
import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt
import csv
from PIL import Image
import io

# Lista para guardar imágenes del entrenamiento
frames = []

# =====================================================
# SOLUCIÓN EXACTA DEL OSCILADOR ARMÓNICO AMORTIGUADO
# =====================================================
def exact_solution(d, w0, t):
    assert d < w0
    w = np.sqrt(w0**2 - d**2)
    phi = np.arctan(-d / w)
    A = 1 / (2 * np.cos(phi))
    cos = torch.cos(phi + w * t)
    exp = torch.exp(-d * t)
    u = exp * 2 * A * cos
    return u

# =====================================================
# DEFINICIÓN DE LA RED NEURONAL TOTALMENTE CONECTADA
# =====================================================
class FCN(nn.Module):
    def __init__(self, N_INPUT, N_OUTPUT, N_HIDDEN, N_LAYERS):
        super().__init__()
        activation = nn.Tanh
        self.fcs = nn.Sequential(nn.Linear(N_INPUT, N_HIDDEN), activation())
        self.fch = nn.Sequential(*[
            nn.Sequential(nn.Linear(N_HIDDEN, N_HIDDEN), activation())
            for _ in range(N_LAYERS - 1)
        ])
        self.fce = nn.Linear(N_HIDDEN, N_OUTPUT)

    def forward(self, x):
        x = self.fcs(x)
        x = self.fch(x)
        x = self.fce(x)
        return x

# =====================================================
# ENTRENAMIENTO DEL MODELO PINN
# =====================================================
torch.manual_seed(123)

with open("training_metrics.csv", mode="w", newline="") as file:
    writer = csv.writer(file)
    writer.writerow(["Iteration", "Total_Loss", "Loss1", "Loss2", "Loss3", "MSE"])

pinn = FCN(1, 1, 24, 2)

t_boundary = torch.tensor(0.).view(-1, 1).requires_grad_(True)
t_physics = torch.linspace(0, 1, 30).view(-1, 1).requires_grad_(True)

d, w0 = 2, 20
mu, k = 2 * d, w0 ** 2

t_test = torch.linspace(0, 1, 300).view(-1, 1)
u_exact = exact_solution(d, w0, t_test)

optimiser = torch.optim.Adam(pinn.parameters(), lr=1e-3)

for i in range(10001):
    optimiser.zero_grad()

    lambda1, lambda2 = 1e-1, 1e-4

    # Condiciones iniciales
    u_b = pinn(t_boundary)
    loss1 = (torch.squeeze(u_b) - 1) ** 2
    dudt_b = torch.autograd.grad(u_b, t_boundary, torch.ones_like(u_b), create_graph=True)[0]
    loss2 = (torch.squeeze(dudt_b) - 0) ** 2

    # Física
    u_p = pinn(t_physics)
    dudt = torch.autograd.grad(u_p, t_physics, torch.ones_like(u_p), create_graph=True)[0]
    d2udt2 = torch.autograd.grad(dudt, t_physics, torch.ones_like(dudt), create_graph=True)[0]
    loss3 = torch.mean((d2udt2 + mu * dudt + k * u_p) ** 2)

    loss = loss1 + lambda1 * loss2 + lambda2 * loss3
    loss.backward()
    optimiser.step()

    u_pred = pinn(t_test).detach()
    mse = torch.mean((u_pred - u_exact) ** 2).item()

    if i % 100 == 0:
        with open("training_metrics.csv", mode="a", newline="") as file:
            writer = csv.writer(file)
            writer.writerow([i, loss.item(), loss1.item(), loss2.item(), loss3.item(), mse])

        print(f"[{i:5d}] Loss: {loss.item():.4e} | "
              f"Loss1 (u(0)-1)^2: {loss1.item():.2e} | "
              f"Loss2 (u'(0))^2: {loss2.item():.2e} | "
              f"Loss3 (PDE): {loss3.item():.2e} | "
              f"MSE vs exact: {mse:.2e}")

        # Gráfica y captura de imagen
        fig, ax = plt.subplots(figsize=(6, 2.5))
        ax.scatter(t_physics.detach()[:, 0], torch.zeros_like(t_physics)[:, 0],
                   s=20, lw=0, color="tab:green", alpha=0.6, label="Physics points")
        ax.scatter(t_boundary.detach()[:, 0], torch.zeros_like(t_boundary)[:, 0],
                   s=20, lw=0, color="tab:red", alpha=0.6, label="Boundary point")
        ax.plot(t_test[:, 0], u_exact[:, 0], label="Exact solution", color="tab:grey", alpha=0.6)
        ax.plot(t_test[:, 0], u_pred[:, 0], label="PINN solution", color="tab:green")
        ax.set_title(f"Step {i}")
        ax.legend()
        plt.tight_layout()

        buf = io.BytesIO()
        plt.savefig(buf, format='png')
        buf.seek(0)
        frames.append(Image.open(buf))
        plt.close()

# Guardar GIF
frames[0].save("pinn_training.gif", format='GIF',
               append_images=frames[1:], save_all=True,
               duration=120, loop=0)
# Out:
# [    0] Loss: 1.1160e+00 | Loss1 (u(0)-1)^2: 6.67e-01 | Loss2 (u'(0))^2: 9.37e-04 | Loss3 (PDE): 4.49e+03 | MSE vs exact: 1.44e-01
# [  100] Loss: 7.9568e-01 | Loss1 (u(0)-1)^2: 6.43e-01 | Loss2 (u'(0))^2: 1.09e-01 | Loss3 (PDE): 1.41e+03 | MSE vs exact: 1.33e-01
# [  200] Loss: 7.6185e-01 | Loss1 (u(0)-1)^2: 6.01e-01 | Loss2 (u'(0))^2: 2.52e-01 | Loss3 (PDE): 1.36e+03 | MSE vs exact: 1.30e-01
# [  300] Loss: 7.1148e-01 | Loss1 (u(0)-1)^2: 5.18e-01 | Loss2 (u'(0))^2: 3.84e-01 | Loss3 (PDE): 1.55e+03 | MSE vs exact: 1.29e-01
# [  400] Loss: 6.6235e-01 | Loss1 (u(0)-1)^2: 4.42e-01 | Loss2 (u'(0))^2: 3.42e-01 | Loss3 (PDE): 1.86e+03 | MSE vs exact: 1.29e-01
# [  500] Loss: 5.6738e-01 | Loss1 (u(0)-1)^2: 3.55e-01 | Loss2 (u'(0))^2: 2.40e-01 | Loss3 (PDE): 1.88e+03 | MSE vs exact: 1.19e-01
# [  600] Loss: 4.1156e-01 | Loss1 (u(0)-1)^2: 2.41e-01 | Loss2 (u'(0))^2: 9.67e-02 | Loss3 (PDE): 1.61e+03 | MSE vs exact: 9.59e-02
# [  700] Loss: 3.0842e-01 | Loss1 (u(0)-1)^2: 1.50e-01 | Loss2 (u'(0))^2: 2.83e-02 | Loss3 (PDE): 1.56e+03 | MSE vs exact: 8.12e-02
# [  800] Loss: 2.6563e-01 | Loss1 (u(0)-1)^2: 1.11e-01 | Loss2 (u'(0))^2: 1.93e-02 | Loss3 (PDE): 1.52e+03 | MSE vs exact: 7.83e-02
# [  900] Loss: 2.2800e-01 | Loss1 (u(0)-1)^2: 8.49e-02 | Loss2 (u'(0))^2: 5.38e-03 | Loss3 (PDE): 1.43e+03 | MSE vs exact: 7.72e-02
# [ 1000] Loss: 2.0112e-01 | Loss1 (u(0)-1)^2: 6.53e-02 | Loss2 (u'(0))^2: 6.53e-04 | Loss3 (PDE): 1.36e+03 | MSE vs exact: 7.61e-02
# [ 1100] Loss: 1.8340e-01 | Loss1 (u(0)-1)^2: 5.36e-02 | Loss2 (u'(0))^2: 4.77e-05 | Loss3 (PDE): 1.30e+03 | MSE vs exact: 7.45e-02
# [ 1200] Loss: 1.6903e-01 | Loss1 (u(0)-1)^2: 4.61e-02 | Loss2 (u'(0))^2: 1.02e-05 | Loss3 (PDE): 1.23e+03 | MSE vs exact: 7.23e-02
# [ 1300] Loss: 1.5469e-01 | Loss1 (u(0)-1)^2: 4.01e-02 | Loss2 (u'(0))^2: 5.34e-05 | Loss3 (PDE): 1.15e+03 | MSE vs exact: 6.91e-02
# [ 1400] Loss: 1.3752e-01 | Loss1 (u(0)-1)^2: 3.36e-02 | Loss2 (u'(0))^2: 1.90e-03 | Loss3 (PDE): 1.04e+03 | MSE vs exact: 6.39e-02
# [ 1500] Loss: 1.1303e-01 | Loss1 (u(0)-1)^2: 2.60e-02 | Loss2 (u'(0))^2: 8.39e-07 | Loss3 (PDE): 8.71e+02 | MSE vs exact: 5.53e-02
# [ 1600] Loss: 8.0565e-02 | Loss1 (u(0)-1)^2: 1.62e-02 | Loss2 (u'(0))^2: 4.74e-07 | Loss3 (PDE): 6.43e+02 | MSE vs exact: 4.35e-02
# [ 1700] Loss: 5.4501e-02 | Loss1 (u(0)-1)^2: 7.64e-03 | Loss2 (u'(0))^2: 7.97e-06 | Loss3 (PDE): 4.69e+02 | MSE vs exact: 3.30e-02
# [ 1800] Loss: 4.5883e-02 | Loss1 (u(0)-1)^2: 3.79e-03 | Loss2 (u'(0))^2: 1.60e-05 | Loss3 (PDE): 4.21e+02 | MSE vs exact: 2.82e-02
# [ 1900] Loss: 4.2689e-02 | Loss1 (u(0)-1)^2: 2.64e-03 | Loss2 (u'(0))^2: 1.59e-03 | Loss3 (PDE): 3.99e+02 | MSE vs exact: 2.64e-02
# [ 2000] Loss: 4.0051e-02 | Loss1 (u(0)-1)^2: 2.24e-03 | Loss2 (u'(0))^2: 4.32e-06 | Loss3 (PDE): 3.78e+02 | MSE vs exact: 2.52e-02
# [ 2100] Loss: 3.8234e-02 | Loss1 (u(0)-1)^2: 2.06e-03 | Loss2 (u'(0))^2: 9.91e-06 | Loss3 (PDE): 3.62e+02 | MSE vs exact: 2.42e-02
# [ 2200] Loss: 3.6967e-02 | Loss1 (u(0)-1)^2: 1.95e-03 | Loss2 (u'(0))^2: 2.13e-08 | Loss3 (PDE): 3.50e+02 | MSE vs exact: 2.34e-02
# [ 2300] Loss: 3.6126e-02 | Loss1 (u(0)-1)^2: 1.83e-03 | Loss2 (u'(0))^2: 1.18e-03 | Loss3 (PDE): 3.42e+02 | MSE vs exact: 2.28e-02
# [ 2400] Loss: 3.5090e-02 | Loss1 (u(0)-1)^2: 1.76e-03 | Loss2 (u'(0))^2: 2.64e-08 | Loss3 (PDE): 3.33e+02 | MSE vs exact: 2.22e-02
# [ 2500] Loss: 3.4193e-02 | Loss1 (u(0)-1)^2: 1.67e-03 | Loss2 (u'(0))^2: 6.62e-04 | Loss3 (PDE): 3.25e+02 | MSE vs exact: 2.17e-02
# [ 2600] Loss: 3.3051e-02 | Loss1 (u(0)-1)^2: 1.52e-03 | Loss2 (u'(0))^2: 1.14e-07 | Loss3 (PDE): 3.15e+02 | MSE vs exact: 2.10e-02
# [ 2700] Loss: 3.1821e-02 | Loss1 (u(0)-1)^2: 1.38e-03 | Loss2 (u'(0))^2: 3.38e-07 | Loss3 (PDE): 3.04e+02 | MSE vs exact: 2.03e-02
# [ 2800] Loss: 3.0428e-02 | Loss1 (u(0)-1)^2: 1.23e-03 | Loss2 (u'(0))^2: 2.69e-07 | Loss3 (PDE): 2.92e+02 | MSE vs exact: 1.95e-02
# [ 2900] Loss: 2.8879e-02 | Loss1 (u(0)-1)^2: 1.07e-03 | Loss2 (u'(0))^2: 4.28e-09 | Loss3 (PDE): 2.78e+02 | MSE vs exact: 1.86e-02
# [ 3000] Loss: 2.7259e-02 | Loss1 (u(0)-1)^2: 9.25e-04 | Loss2 (u'(0))^2: 1.59e-05 | Loss3 (PDE): 2.63e+02 | MSE vs exact: 1.76e-02
# [ 3100] Loss: 2.5656e-02 | Loss1 (u(0)-1)^2: 8.00e-04 | Loss2 (u'(0))^2: 8.85e-09 | Loss3 (PDE): 2.49e+02 | MSE vs exact: 1.66e-02
# [ 3200] Loss: 2.4130e-02 | Loss1 (u(0)-1)^2: 7.04e-04 | Loss2 (u'(0))^2: 3.34e-07 | Loss3 (PDE): 2.34e+02 | MSE vs exact: 1.57e-02
# [ 3300] Loss: 2.2739e-02 | Loss1 (u(0)-1)^2: 6.18e-04 | Loss2 (u'(0))^2: 6.12e-08 | Loss3 (PDE): 2.21e+02 | MSE vs exact: 1.48e-02
# [ 3400] Loss: 2.1422e-02 | Loss1 (u(0)-1)^2: 5.70e-04 | Loss2 (u'(0))^2: 1.25e-04 | Loss3 (PDE): 2.08e+02 | MSE vs exact: 1.40e-02
# [ 3500] Loss: 2.0151e-02 | Loss1 (u(0)-1)^2: 5.17e-04 | Loss2 (u'(0))^2: 5.54e-08 | Loss3 (PDE): 1.96e+02 | MSE vs exact: 1.32e-02
# [ 3600] Loss: 1.8986e-02 | Loss1 (u(0)-1)^2: 4.81e-04 | Loss2 (u'(0))^2: 3.39e-04 | Loss3 (PDE): 1.85e+02 | MSE vs exact: 1.25e-02
# [ 3700] Loss: 1.7828e-02 | Loss1 (u(0)-1)^2: 4.53e-04 | Loss2 (u'(0))^2: 3.88e-09 | Loss3 (PDE): 1.74e+02 | MSE vs exact: 1.18e-02
# [ 3800] Loss: 1.6815e-02 | Loss1 (u(0)-1)^2: 4.19e-04 | Loss2 (u'(0))^2: 3.70e-05 | Loss3 (PDE): 1.64e+02 | MSE vs exact: 1.10e-02
# [ 3900] Loss: 1.5914e-02 | Loss1 (u(0)-1)^2: 3.86e-04 | Loss2 (u'(0))^2: 1.63e-09 | Loss3 (PDE): 1.55e+02 | MSE vs exact: 1.03e-02
# [ 4000] Loss: 1.5145e-02 | Loss1 (u(0)-1)^2: 3.49e-04 | Loss2 (u'(0))^2: 8.58e-06 | Loss3 (PDE): 1.48e+02 | MSE vs exact: 9.67e-03
# [ 4100] Loss: 1.4519e-02 | Loss1 (u(0)-1)^2: 3.18e-04 | Loss2 (u'(0))^2: 1.98e-08 | Loss3 (PDE): 1.42e+02 | MSE vs exact: 9.09e-03
# [ 4200] Loss: 1.4047e-02 | Loss1 (u(0)-1)^2: 2.96e-04 | Loss2 (u'(0))^2: 1.73e-04 | Loss3 (PDE): 1.37e+02 | MSE vs exact: 8.58e-03
# [ 4300] Loss: 1.3619e-02 | Loss1 (u(0)-1)^2: 2.64e-04 | Loss2 (u'(0))^2: 7.26e-08 | Loss3 (PDE): 1.34e+02 | MSE vs exact: 8.18e-03
# [ 4400] Loss: 1.4411e-02 | Loss1 (u(0)-1)^2: 2.11e-04 | Loss2 (u'(0))^2: 6.27e-03 | Loss3 (PDE): 1.36e+02 | MSE vs exact: 7.90e-03
# [ 4500] Loss: 1.2976e-02 | Loss1 (u(0)-1)^2: 2.28e-04 | Loss2 (u'(0))^2: 2.64e-08 | Loss3 (PDE): 1.27e+02 | MSE vs exact: 7.52e-03
# [ 4600] Loss: 1.2686e-02 | Loss1 (u(0)-1)^2: 2.14e-04 | Loss2 (u'(0))^2: 3.05e-09 | Loss3 (PDE): 1.25e+02 | MSE vs exact: 7.24e-03
# [ 4700] Loss: 1.2409e-02 | Loss1 (u(0)-1)^2: 2.02e-04 | Loss2 (u'(0))^2: 2.70e-06 | Loss3 (PDE): 1.22e+02 | MSE vs exact: 7.00e-03
# [ 4800] Loss: 1.2133e-02 | Loss1 (u(0)-1)^2: 1.92e-04 | Loss2 (u'(0))^2: 1.08e-07 | Loss3 (PDE): 1.19e+02 | MSE vs exact: 6.76e-03
# [ 4900] Loss: 1.1887e-02 | Loss1 (u(0)-1)^2: 1.90e-04 | Loss2 (u'(0))^2: 2.23e-04 | Loss3 (PDE): 1.17e+02 | MSE vs exact: 6.53e-03
# [ 5000] Loss: 1.1571e-02 | Loss1 (u(0)-1)^2: 1.73e-04 | Loss2 (u'(0))^2: 1.36e-07 | Loss3 (PDE): 1.14e+02 | MSE vs exact: 6.31e-03
# [ 5100] Loss: 1.1423e-02 | Loss1 (u(0)-1)^2: 1.80e-04 | Loss2 (u'(0))^2: 9.10e-04 | Loss3 (PDE): 1.12e+02 | MSE vs exact: 6.06e-03
# [ 5200] Loss: 1.0996e-02 | Loss1 (u(0)-1)^2: 1.55e-04 | Loss2 (u'(0))^2: 1.29e-07 | Loss3 (PDE): 1.08e+02 | MSE vs exact: 5.86e-03
# [ 5300] Loss: 1.0844e-02 | Loss1 (u(0)-1)^2: 1.36e-04 | Loss2 (u'(0))^2: 1.03e-03 | Loss3 (PDE): 1.06e+02 | MSE vs exact: 5.67e-03
# [ 5400] Loss: 1.0406e-02 | Loss1 (u(0)-1)^2: 1.39e-04 | Loss2 (u'(0))^2: 3.59e-08 | Loss3 (PDE): 1.03e+02 | MSE vs exact: 5.43e-03
# [ 5500] Loss: 1.0101e-02 | Loss1 (u(0)-1)^2: 1.30e-04 | Loss2 (u'(0))^2: 1.50e-06 | Loss3 (PDE): 9.97e+01 | MSE vs exact: 5.21e-03
# [ 5600] Loss: 9.7894e-03 | Loss1 (u(0)-1)^2: 1.23e-04 | Loss2 (u'(0))^2: 1.35e-06 | Loss3 (PDE): 9.67e+01 | MSE vs exact: 4.99e-03
# [ 5700] Loss: 9.4599e-03 | Loss1 (u(0)-1)^2: 1.15e-04 | Loss2 (u'(0))^2: 3.15e-08 | Loss3 (PDE): 9.34e+01 | MSE vs exact: 4.77e-03
# [ 5800] Loss: 9.1111e-03 | Loss1 (u(0)-1)^2: 1.09e-04 | Loss2 (u'(0))^2: 1.06e-05 | Loss3 (PDE): 9.00e+01 | MSE vs exact: 4.54e-03
# [ 5900] Loss: 8.7250e-03 | Loss1 (u(0)-1)^2: 1.01e-04 | Loss2 (u'(0))^2: 1.24e-07 | Loss3 (PDE): 8.62e+01 | MSE vs exact: 4.31e-03
# [ 6000] Loss: 8.3003e-03 | Loss1 (u(0)-1)^2: 9.45e-05 | Loss2 (u'(0))^2: 6.25e-06 | Loss3 (PDE): 8.21e+01 | MSE vs exact: 4.04e-03
# [ 6100] Loss: 7.8184e-03 | Loss1 (u(0)-1)^2: 8.67e-05 | Loss2 (u'(0))^2: 1.19e-07 | Loss3 (PDE): 7.73e+01 | MSE vs exact: 3.75e-03
# [ 6200] Loss: 7.4077e-03 | Loss1 (u(0)-1)^2: 7.77e-05 | Loss2 (u'(0))^2: 9.13e-04 | Loss3 (PDE): 7.24e+01 | MSE vs exact: 3.42e-03
# [ 6300] Loss: 6.6934e-03 | Loss1 (u(0)-1)^2: 6.93e-05 | Loss2 (u'(0))^2: 2.64e-07 | Loss3 (PDE): 6.62e+01 | MSE vs exact: 3.07e-03
# [ 6400] Loss: 6.0759e-03 | Loss1 (u(0)-1)^2: 5.91e-05 | Loss2 (u'(0))^2: 1.09e-04 | Loss3 (PDE): 6.01e+01 | MSE vs exact: 2.68e-03
# [ 6500] Loss: 5.4001e-03 | Loss1 (u(0)-1)^2: 5.10e-05 | Loss2 (u'(0))^2: 4.22e-09 | Loss3 (PDE): 5.35e+01 | MSE vs exact: 2.32e-03
# [ 6600] Loss: 4.7171e-03 | Loss1 (u(0)-1)^2: 3.96e-05 | Loss2 (u'(0))^2: 1.13e-04 | Loss3 (PDE): 4.67e+01 | MSE vs exact: 1.97e-03
# [ 6700] Loss: 4.0115e-03 | Loss1 (u(0)-1)^2: 3.62e-05 | Loss2 (u'(0))^2: 1.25e-08 | Loss3 (PDE): 3.98e+01 | MSE vs exact: 1.64e-03
# [ 6800] Loss: 3.4811e-03 | Loss1 (u(0)-1)^2: 2.99e-05 | Loss2 (u'(0))^2: 7.05e-04 | Loss3 (PDE): 3.38e+01 | MSE vs exact: 1.36e-03
# [ 6900] Loss: 2.8016e-03 | Loss1 (u(0)-1)^2: 2.64e-05 | Loss2 (u'(0))^2: 2.26e-08 | Loss3 (PDE): 2.78e+01 | MSE vs exact: 1.10e-03
# [ 7000] Loss: 2.3454e-03 | Loss1 (u(0)-1)^2: 2.27e-05 | Loss2 (u'(0))^2: 3.73e-08 | Loss3 (PDE): 2.32e+01 | MSE vs exact: 8.97e-04
# [ 7100] Loss: 2.0305e-03 | Loss1 (u(0)-1)^2: 1.99e-05 | Loss2 (u'(0))^2: 1.41e-06 | Loss3 (PDE): 2.01e+01 | MSE vs exact: 7.44e-04
# [ 7200] Loss: 1.7841e-03 | Loss1 (u(0)-1)^2: 1.76e-05 | Loss2 (u'(0))^2: 2.22e-10 | Loss3 (PDE): 1.77e+01 | MSE vs exact: 6.24e-04
# [ 7300] Loss: 1.5913e-03 | Loss1 (u(0)-1)^2: 1.65e-05 | Loss2 (u'(0))^2: 5.74e-05 | Loss3 (PDE): 1.57e+01 | MSE vs exact: 5.44e-04
# [ 7400] Loss: 1.4152e-03 | Loss1 (u(0)-1)^2: 1.38e-05 | Loss2 (u'(0))^2: 8.88e-09 | Loss3 (PDE): 1.40e+01 | MSE vs exact: 4.56e-04
# [ 7500] Loss: 2.5973e-03 | Loss1 (u(0)-1)^2: 5.81e-06 | Loss2 (u'(0))^2: 5.86e-03 | Loss3 (PDE): 2.01e+01 | MSE vs exact: 4.92e-04
# [ 7600] Loss: 1.1446e-03 | Loss1 (u(0)-1)^2: 1.09e-05 | Loss2 (u'(0))^2: 1.24e-07 | Loss3 (PDE): 1.13e+01 | MSE vs exact: 3.45e-04
# [ 7700] Loss: 1.0340e-03 | Loss1 (u(0)-1)^2: 9.72e-06 | Loss2 (u'(0))^2: 8.56e-08 | Loss3 (PDE): 1.02e+01 | MSE vs exact: 3.01e-04
# [ 7800] Loss: 9.4256e-04 | Loss1 (u(0)-1)^2: 8.74e-06 | Loss2 (u'(0))^2: 3.16e-06 | Loss3 (PDE): 9.34e+00 | MSE vs exact: 2.64e-04
# [ 7900] Loss: 8.6096e-04 | Loss1 (u(0)-1)^2: 7.71e-06 | Loss2 (u'(0))^2: 1.04e-09 | Loss3 (PDE): 8.53e+00 | MSE vs exact: 2.33e-04
# [ 8000] Loss: 7.9587e-04 | Loss1 (u(0)-1)^2: 6.69e-06 | Loss2 (u'(0))^2: 1.66e-05 | Loss3 (PDE): 7.88e+00 | MSE vs exact: 2.09e-04
# [ 8100] Loss: 7.3424e-04 | Loss1 (u(0)-1)^2: 6.15e-06 | Loss2 (u'(0))^2: 1.12e-08 | Loss3 (PDE): 7.28e+00 | MSE vs exact: 1.84e-04
# [ 8200] Loss: 6.8934e-04 | Loss1 (u(0)-1)^2: 5.23e-06 | Loss2 (u'(0))^2: 2.40e-05 | Loss3 (PDE): 6.82e+00 | MSE vs exact: 1.66e-04
# [ 8300] Loss: 6.4293e-04 | Loss1 (u(0)-1)^2: 4.95e-06 | Loss2 (u'(0))^2: 4.26e-08 | Loss3 (PDE): 6.38e+00 | MSE vs exact: 1.50e-04
# [ 8400] Loss: 6.5491e-04 | Loss1 (u(0)-1)^2: 5.11e-06 | Loss2 (u'(0))^2: 2.41e-04 | Loss3 (PDE): 6.26e+00 | MSE vs exact: 1.33e-04
# [ 8500] Loss: 5.7732e-04 | Loss1 (u(0)-1)^2: 4.06e-06 | Loss2 (u'(0))^2: 4.30e-10 | Loss3 (PDE): 5.73e+00 | MSE vs exact: 1.25e-04
# [ 8600] Loss: 6.1292e-04 | Loss1 (u(0)-1)^2: 5.69e-06 | Loss2 (u'(0))^2: 3.13e-04 | Loss3 (PDE): 5.76e+00 | MSE vs exact: 1.17e-04
# [ 8700] Loss: 5.2950e-04 | Loss1 (u(0)-1)^2: 3.34e-06 | Loss2 (u'(0))^2: 9.25e-08 | Loss3 (PDE): 5.26e+00 | MSE vs exact: 1.08e-04
# [ 8800] Loss: 1.8029e-03 | Loss1 (u(0)-1)^2: 4.68e-07 | Loss2 (u'(0))^2: 6.53e-03 | Loss3 (PDE): 1.15e+01 | MSE vs exact: 1.72e-04
# [ 8900] Loss: 4.9404e-04 | Loss1 (u(0)-1)^2: 2.82e-06 | Loss2 (u'(0))^2: 4.42e-09 | Loss3 (PDE): 4.91e+00 | MSE vs exact: 9.61e-05
# [ 9000] Loss: 5.0262e-04 | Loss1 (u(0)-1)^2: 2.12e-06 | Loss2 (u'(0))^2: 1.20e-04 | Loss3 (PDE): 4.88e+00 | MSE vs exact: 9.67e-05
# [ 9100] Loss: 4.6690e-04 | Loss1 (u(0)-1)^2: 2.39e-06 | Loss2 (u'(0))^2: 4.28e-07 | Loss3 (PDE): 4.64e+00 | MSE vs exact: 8.81e-05
# [ 9200] Loss: 4.5651e-04 | Loss1 (u(0)-1)^2: 2.34e-06 | Loss2 (u'(0))^2: 5.66e-06 | Loss3 (PDE): 4.54e+00 | MSE vs exact: 8.41e-05
# [ 9300] Loss: 4.4557e-04 | Loss1 (u(0)-1)^2: 2.06e-06 | Loss2 (u'(0))^2: 7.51e-07 | Loss3 (PDE): 4.43e+00 | MSE vs exact: 8.27e-05
# [ 9400] Loss: 4.3617e-04 | Loss1 (u(0)-1)^2: 1.94e-06 | Loss2 (u'(0))^2: 2.26e-08 | Loss3 (PDE): 4.34e+00 | MSE vs exact: 8.04e-05
# [ 9500] Loss: 4.5247e-04 | Loss1 (u(0)-1)^2: 1.23e-06 | Loss2 (u'(0))^2: 1.31e-04 | Loss3 (PDE): 4.38e+00 | MSE vs exact: 7.95e-05
# [ 9600] Loss: 4.1972e-04 | Loss1 (u(0)-1)^2: 1.72e-06 | Loss2 (u'(0))^2: 8.45e-09 | Loss3 (PDE): 4.18e+00 | MSE vs exact: 7.72e-05
# [ 9700] Loss: 4.8637e-04 | Loss1 (u(0)-1)^2: 1.04e-06 | Loss2 (u'(0))^2: 3.87e-04 | Loss3 (PDE): 4.47e+00 | MSE vs exact: 8.77e-05
# [ 9800] Loss: 4.0535e-04 | Loss1 (u(0)-1)^2: 1.55e-06 | Loss2 (u'(0))^2: 1.77e-10 | Loss3 (PDE): 4.04e+00 | MSE vs exact: 7.49e-05
# [ 9900] Loss: 4.0554e-04 | Loss1 (u(0)-1)^2: 1.92e-06 | Loss2 (u'(0))^2: 3.51e-05 | Loss3 (PDE): 4.00e+00 | MSE vs exact: 8.43e-05
# [10000] Loss: 3.9242e-04 | Loss1 (u(0)-1)^2: 1.40e-06 | Loss2 (u'(0))^2: 2.98e-08 | Loss3 (PDE): 3.91e+00 | MSE vs exact: 7.35e-05

# %%
import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt
import csv
from PIL import Image
import io

# Lista para guardar imágenes del entrenamiento
frames = []

# ============================================
# SOLUCIÓN EXACTA DEL OSCILADOR AMORTIGUADO
# ============================================
def exact_solution(d, w0, t):
    assert d < w0
    w = np.sqrt(w0**2 - d**2)
    phi = np.arctan(-d / w)
    A = 1 / (2 * np.cos(phi))
    cos = torch.cos(phi + w * t)
    exp = torch.exp(-d * t)
    u = exp * 2 * A * cos
    return u

# ============================================
# DEFINICIÓN DE LA RED NEURONAL TOTALMENTE CONECTADA
# ============================================
class FCN(nn.Module):
    def __init__(self, N_INPUT, N_OUTPUT, N_HIDDEN, N_LAYERS):
        super().__init__()
        activation = nn.Tanh
        self.fcs = nn.Sequential(nn.Linear(N_INPUT, N_HIDDEN), activation())
        self.fch = nn.Sequential(*[
            nn.Sequential(nn.Linear(N_HIDDEN, N_HIDDEN), activation())
            for _ in range(N_LAYERS - 1)
        ])
        self.fce = nn.Linear(N_HIDDEN, N_OUTPUT)

    def forward(self, x):
        x = self.fcs(x)
        x = self.fch(x)
        x = self.fce(x)
        return x

# ============================================
# PARÁMETROS DEL SISTEMA Y DATOS DE ENTRENAMIENTO
# ============================================
torch.manual_seed(123)
d, w0 = 2, 20

# Datos sintéticos para entrenamiento (supervisado)
t_train = torch.linspace(0, 1, 30).view(-1, 1)
u_train = exact_solution(d, w0, t_train)

# Guardar datos sintéticos en CSV
with open("synthetic_data.csv", mode="w", newline="") as file:
    writer = csv.writer(file)
    writer.writerow(["t", "u(t)"])
    for t_val, u_val in zip(t_train, u_train):
        writer.writerow([t_val.item(), u_val.item()])

# Datos para evaluación
t_test = torch.linspace(0, 1, 300).view(-1, 1)
u_exact = exact_solution(d, w0, t_test)

# ============================================
# INICIALIZACIÓN DE MODELO Y OPTIMIZADOR
# ============================================
pinn = FCN(1, 1, 24, 2)
optimiser = torch.optim.Adam(pinn.parameters(), lr=1e-3)

# ============================================
# ARCHIVO PARA GUARDAR MÉTRICAS
# ============================================
with open("training_metrics.csv", mode="w", newline="") as file:
    writer = csv.writer(file)
    writer.writerow(["Iteration", "Loss", "MSE"])

# ============================================
# BUCLE DE ENTRENAMIENTO SUPERVISADO DIRECTO
# ============================================
for i in range(10001):
    optimiser.zero_grad()

    u_pred = pinn(t_train)
    loss = torch.mean((u_pred - u_train) ** 2)

    loss.backward()
    optimiser.step()

    # Evaluación en test
    u_pred_test = pinn(t_test).detach()
    mse = torch.mean((u_pred_test - u_exact) ** 2).item()

    if i % 100 == 0:
        with open("training_metrics.csv", mode="a", newline="") as file:
            writer = csv.writer(file)
            writer.writerow([i, loss.item(), mse])

        print(f"[{i:5d}] Loss (train): {loss.item():.4e} | MSE (test): {mse:.4e}")

        # Gráfica y captura de imagen
        fig, ax = plt.subplots(figsize=(6, 2.5))
        ax.scatter(t_train[:, 0], u_train[:, 0],
                   s=20, lw=0, color="tab:blue", alpha=0.6, label="Training data")
        ax.plot(t_test[:, 0], u_exact[:, 0], label="Exact solution", color="tab:grey", alpha=0.6)
        ax.plot(t_test[:, 0], u_pred_test[:, 0], label="NN prediction", color="tab:green")
        ax.set_title(f"Step {i}")
        ax.legend()
        plt.tight_layout()

        buf = io.BytesIO()
        plt.savefig(buf, format='png')
        buf.seek(0)
        frames.append(Image.open(buf))
        plt.close()

# Guardar GIF del entrenamiento
frames[0].save("nn_training.gif", format='GIF',
               append_images=frames[1:], save_all=True,
               duration=120, loop=0)
# Out:
# [    0] Loss (train): 1.5699e-01 | MSE (test): 1.4414e-01
# [  100] Loss (train): 1.3642e-01 | MSE (test): 1.2833e-01
# [  200] Loss (train): 1.3229e-01 | MSE (test): 1.2562e-01
# [  300] Loss (train): 1.1927e-01 | MSE (test): 1.1665e-01
# [  400] Loss (train): 9.6980e-02 | MSE (test): 9.8061e-02
# [  500] Loss (train): 7.1014e-02 | MSE (test): 7.2694e-02
# [  600] Loss (train): 4.6074e-02 | MSE (test): 4.7244e-02
# [  700] Loss (train): 2.9418e-02 | MSE (test): 3.0206e-02
# [  800] Loss (train): 2.1836e-02 | MSE (test): 2.2467e-02
# [  900] Loss (train): 1.9159e-02 | MSE (test): 1.9742e-02
# [ 1000] Loss (train): 1.5934e-02 | MSE (test): 1.6378e-02
# [ 1100] Loss (train): 1.1765e-02 | MSE (test): 1.2017e-02
# [ 1200] Loss (train): 9.5676e-03 | MSE (test): 9.7826e-03
# [ 1300] Loss (train): 7.9102e-03 | MSE (test): 8.0892e-03
# [ 1400] Loss (train): 4.0959e-03 | MSE (test): 4.1972e-03
# [ 1500] Loss (train): 1.1917e-03 | MSE (test): 1.0379e-03
# [ 1600] Loss (train): 8.3816e-04 | MSE (test): 6.6911e-04
# [ 1700] Loss (train): 7.0256e-04 | MSE (test): 5.4376e-04
# [ 1800] Loss (train): 6.2307e-04 | MSE (test): 4.7386e-04
# [ 1900] Loss (train): 5.6724e-04 | MSE (test): 4.2740e-04
# [ 2000] Loss (train): 5.2229e-04 | MSE (test): 3.9166e-04
# [ 2100] Loss (train): 4.8257e-04 | MSE (test): 3.6101e-04
# [ 2200] Loss (train): 4.4572e-04 | MSE (test): 3.3311e-04
# [ 2300] Loss (train): 4.1092e-04 | MSE (test): 3.0712e-04
# [ 2400] Loss (train): 3.7782e-04 | MSE (test): 2.8271e-04
# [ 2500] Loss (train): 3.4608e-04 | MSE (test): 2.5960e-04
# [ 2600] Loss (train): 3.1508e-04 | MSE (test): 2.3745e-04
# [ 2700] Loss (train): 2.8390e-04 | MSE (test): 2.1571e-04
# [ 2800] Loss (train): 2.5147e-04 | MSE (test): 1.9382e-04
# [ 2900] Loss (train): 2.1918e-04 | MSE (test): 1.7546e-04
# [ 3000] Loss (train): 1.8671e-04 | MSE (test): 1.5174e-04
# [ 3100] Loss (train): 1.5836e-04 | MSE (test): 1.3373e-04
# [ 3200] Loss (train): 1.3264e-04 | MSE (test): 1.1815e-04
# [ 3300] Loss (train): 1.1024e-04 | MSE (test): 1.0355e-04
# [ 3400] Loss (train): 9.4186e-05 | MSE (test): 9.1088e-05
# [ 3500] Loss (train): 9.4945e-05 | MSE (test): 9.4241e-05
# [ 3600] Loss (train): 7.4515e-05 | MSE (test): 7.4311e-05
# [ 3700] Loss (train): 6.7963e-05 | MSE (test): 6.8500e-05
# [ 3800] Loss (train): 6.2621e-05 | MSE (test): 6.3721e-05
# [ 3900] Loss (train): 5.8006e-05 | MSE (test): 5.9783e-05
# [ 4000] Loss (train): 5.7528e-05 | MSE (test): 5.6205e-05
# [ 4100] Loss (train): 5.0181e-05 | MSE (test): 5.3046e-05
# [ 4200] Loss (train): 4.6731e-05 | MSE (test): 5.0040e-05
# [ 4300] Loss (train): 4.3661e-05 | MSE (test): 4.7460e-05
# [ 4400] Loss (train): 4.0730e-05 | MSE (test): 4.4936e-05
# [ 4500] Loss (train): 3.9398e-05 | MSE (test): 4.4467e-05
# [ 4600] Loss (train): 3.5407e-05 | MSE (test): 4.0316e-05
# [ 4700] Loss (train): 3.7280e-05 | MSE (test): 3.9760e-05
# [ 4800] Loss (train): 3.0612e-05 | MSE (test): 3.6116e-05
# [ 4900] Loss (train): 2.8405e-05 | MSE (test): 3.4046e-05
# [ 5000] Loss (train): 2.6194e-05 | MSE (test): 3.2240e-05
# [ 5100] Loss (train): 2.4181e-05 | MSE (test): 3.0357e-05
# [ 5200] Loss (train): 2.2405e-05 | MSE (test): 2.8685e-05
# [ 5300] Loss (train): 2.0441e-05 | MSE (test): 2.7191e-05
# [ 5400] Loss (train): 2.9249e-05 | MSE (test): 3.3227e-05
# [ 5500] Loss (train): 1.7248e-05 | MSE (test): 2.4417e-05
# [ 5600] Loss (train): 1.5897e-05 | MSE (test): 2.3319e-05
# [ 5700] Loss (train): 3.0082e-05 | MSE (test): 2.9182e-05
# [ 5800] Loss (train): 1.3624e-05 | MSE (test): 2.1429e-05
# [ 5900] Loss (train): 1.2934e-05 | MSE (test): 2.0820e-05
# [ 6000] Loss (train): 1.1897e-05 | MSE (test): 2.0057e-05
# [ 6100] Loss (train): 1.1196e-05 | MSE (test): 1.9372e-05
# [ 6200] Loss (train): 1.0514e-05 | MSE (test): 1.8835e-05
# [ 6300] Loss (train): 1.0453e-05 | MSE (test): 1.8793e-05
# [ 6400] Loss (train): 9.4270e-06 | MSE (test): 1.8020e-05
# [ 6500] Loss (train): 9.3902e-06 | MSE (test): 1.7835e-05
# [ 6600] Loss (train): 8.3411e-06 | MSE (test): 1.7029e-05
# [ 6700] Loss (train): 8.7744e-06 | MSE (test): 1.7713e-05
# [ 6800] Loss (train): 8.2659e-06 | MSE (test): 1.6441e-05
# [ 6900] Loss (train): 8.6954e-06 | MSE (test): 1.8775e-05
# [ 7000] Loss (train): 6.6507e-06 | MSE (test): 1.5603e-05
# [ 7100] Loss (train): 1.5076e-05 | MSE (test): 2.1933e-05
# [ 7200] Loss (train): 6.2272e-06 | MSE (test): 1.5489e-05
# [ 7300] Loss (train): 5.6307e-06 | MSE (test): 1.4764e-05
# [ 7400] Loss (train): 5.5333e-06 | MSE (test): 1.4949e-05
# [ 7500] Loss (train): 1.8529e-05 | MSE (test): 1.6603e-05
# [ 7600] Loss (train): 4.7961e-06 | MSE (test): 1.4036e-05
# [ 7700] Loss (train): 4.5515e-06 | MSE (test): 1.3852e-05
# [ 7800] Loss (train): 4.4762e-06 | MSE (test): 1.3691e-05
# [ 7900] Loss (train): 4.1159e-06 | MSE (test): 1.3494e-05
# [ 8000] Loss (train): 4.1882e-06 | MSE (test): 1.3607e-05
# [ 8100] Loss (train): 3.7386e-06 | MSE (test): 1.3180e-05
# [ 8200] Loss (train): 1.5557e-05 | MSE (test): 3.0320e-05
# [ 8300] Loss (train): 3.4069e-06 | MSE (test): 1.2887e-05
# [ 8400] Loss (train): 1.5753e-05 | MSE (test): 2.2350e-05
# [ 8500] Loss (train): 3.1206e-06 | MSE (test): 1.2653e-05
# [ 8600] Loss (train): 2.9992e-06 | MSE (test): 1.2533e-05
# [ 8700] Loss (train): 5.9799e-06 | MSE (test): 1.2485e-05
# [ 8800] Loss (train): 2.7504e-06 | MSE (test): 1.2321e-05
# [ 8900] Loss (train): 2.7086e-06 | MSE (test): 1.2385e-05
# [ 9000] Loss (train): 2.5448e-06 | MSE (test): 1.2125e-05
# [ 9100] Loss (train): 4.1936e-06 | MSE (test): 1.4586e-05
# [ 9200] Loss (train): 2.3606e-06 | MSE (test): 1.1945e-05
# [ 9300] Loss (train): 2.3045e-06 | MSE (test): 1.1884e-05
# [ 9400] Loss (train): 2.2840e-06 | MSE (test): 1.1825e-05
# [ 9500] Loss (train): 2.1258e-06 | MSE (test): 1.1696e-05
# [ 9600] Loss (train): 2.0567e-06 | MSE (test): 1.1628e-05
# [ 9700] Loss (train): 7.9060e-06 | MSE (test): 1.3636e-05
# [ 9800] Loss (train): 2.3354e-06 | MSE (test): 1.1798e-05
# [ 9900] Loss (train): 4.4519e-06 | MSE (test): 1.5352e-05
# [10000] Loss (train): 1.8140e-06 | MSE (test): 1.1325e-05

# %%
import matplotlib.pyplot as plt
import csv

# Listas para almacenar los datos
iterations = []
losses = []
mses = []

# Leer el archivo CSV
with open("training_metrics.csv", mode="r") as file:
    reader = csv.DictReader(file)
    for row in reader:
        iterations.append(int(row["Iteration"]))
        losses.append(float(row["Loss"]))
        mses.append(float(row["MSE"]))

# Crear la figura
plt.figure(figsize=(8, 4))

# Graficar el Loss y el MSE
plt.plot(iterations, losses, label="Loss (train)", color="tab:blue")
plt.plot(iterations, mses, label="MSE (test)", color="tab:orange")
plt.xlabel("Iteración")
plt.ylabel("Error")
plt.title("Evolución del error durante el entrenamiento")
plt.legend()
plt.grid(True)
plt.tight_layout()

# Mostrar o guardar la gráfica
plt.savefig("training_error_plot.png")
plt.show()

# %%
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
import networkx as nx

# ============================================
# DEFINICIÓN DE LA RED NEURONAL
# ============================================
class FCN(nn.Module):
    def __init__(self, N_INPUT, N_OUTPUT, N_HIDDEN, N_LAYERS):
        super().__init__()
        activation = nn.Tanh
        self.fcs = nn.Sequential(nn.Linear(N_INPUT, N_HIDDEN), activation())
        self.fch = nn.Sequential(*[
            nn.Sequential(nn.Linear(N_HIDDEN, N_HIDDEN), activation())
            for _ in range(N_LAYERS - 1)
        ])
        self.fce = nn.Linear(N_HIDDEN, N_OUTPUT)

    def forward(self, x):
        x = self.fcs(x)
        x = self.fch(x)
        x = self.fce(x)
        return x

# ============================================
# CREACIÓN DEL MODELO
# ============================================
N_INPUT = 1
N_OUTPUT = 1
N_HIDDEN = 24
N_LAYERS = 2

model = FCN(N_INPUT, N_OUTPUT, N_HIDDEN, N_LAYERS)

# Contar parámetros entrenables
total_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
print(f"Total de parámetros entrenables: {total_params}")

# ============================================
# VISUALIZACIÓN CON NETWORKX
# ============================================
G = nx.DiGraph()
positions = {}
node_id = 0
layer_nodes = []

# Capa de entrada
input_layer = []
for y in range(N_INPUT):
    positions[node_id] = (0, -y)
    input_layer.append(node_id)
    node_id += 1
layer_nodes.append(input_layer)

# Capas ocultas
for i in range(N_LAYERS):
    hidden_layer = []
    for y in range(N_HIDDEN):
        positions[node_id] = (i + 1, -y)
        hidden_layer.append(node_id)
        node_id += 1
    layer_nodes.append(hidden_layer)

# Capa de salida
output_layer = []
for y in range(N_OUTPUT):
    positions[node_id] = (N_LAYERS + 1, -y)
    output_layer.append(node_id)
    node_id += 1
layer_nodes.append(output_layer)

# Conectar nodos capa a capa
for i in range(len(layer_nodes) - 1):
    for a in layer_nodes[i]:
        for b in layer_nodes[i + 1]:
            G.add_edge(a, b)

# Graficar
plt.figure(figsize=(10, 6))
nx.draw(G, pos=positions, node_color='skyblue', with_labels=False, node_size=300, edge_color='gray')
plt.title(f"Arquitectura de la red: {N_INPUT} entrada, {N_LAYERS} capas ocultas de {N_HIDDEN} neuronas, {N_OUTPUT} salida\nTotal de parámetros: {total_params}")
plt.axis('off')
plt.tight_layout()
plt.show()
# Out:
# Total de parámetros entrenables: 673
# <ipython-input-11-62524e24b124>:84: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
