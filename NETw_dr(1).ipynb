# %%
# Importación de librerías esenciales
import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt
import csv
from PIL import Image
import io

# Lista para guardar imágenes del entrenamiento
frames = []

# =====================================================
# SOLUCIÓN EXACTA DEL OSCILADOR ARMÓNICO AMORTIGUADO
# =====================================================
def exact_solution(d, w0, t):
    assert d < w0
    w = np.sqrt(w0**2 - d**2)
    phi = np.arctan(-d / w)
    A = 1 / (2 * np.cos(phi))
    cos = torch.cos(phi + w * t)
    exp = torch.exp(-d * t)
    u = exp * 2 * A * cos
    return u

# =====================================================
# DEFINICIÓN DE LA RED NEURONAL TOTALMENTE CONECTADA
# =====================================================
class FCN(nn.Module):
    def __init__(self, N_INPUT, N_OUTPUT, N_HIDDEN, N_LAYERS):
        super().__init__()
        activation = nn.Tanh
        self.fcs = nn.Sequential(nn.Linear(N_INPUT, N_HIDDEN), activation())
        self.fch = nn.Sequential(*[
            nn.Sequential(nn.Linear(N_HIDDEN, N_HIDDEN), activation())
            for _ in range(N_LAYERS - 1)
        ])
        self.fce = nn.Linear(N_HIDDEN, N_OUTPUT)

    def forward(self, x):
        x = self.fcs(x)
        x = self.fch(x)
        x = self.fce(x)
        return x

# =====================================================
# ENTRENAMIENTO DEL MODELO PINN
# =====================================================
torch.manual_seed(123)

with open("training_metrics.csv", mode="w", newline="") as file:
    writer = csv.writer(file)
    writer.writerow(["Iteration", "Total_Loss", "Loss1", "Loss2", "Loss3", "MSE"])

pinn = FCN(1, 1, 8, 2)

t_boundary = torch.tensor(0.).view(-1, 1).requires_grad_(True)
t_physics = torch.linspace(0, 1, 30).view(-1, 1).requires_grad_(True)

d, w0 = 2, 20
mu, k = 2 * d, w0 ** 2

t_test = torch.linspace(0, 1, 300).view(-1, 1)
u_exact = exact_solution(d, w0, t_test)

optimiser = torch.optim.Adam(pinn.parameters(), lr=1e-3)

for i in range(10001):
    optimiser.zero_grad()

    lambda1, lambda2 = 1e-1, 1e-4

    # Condiciones iniciales
    u_b = pinn(t_boundary)
    loss1 = (torch.squeeze(u_b) - 1) ** 2
    dudt_b = torch.autograd.grad(u_b, t_boundary, torch.ones_like(u_b), create_graph=True)[0]
    loss2 = (torch.squeeze(dudt_b) - 0) ** 2

    # Física
    u_p = pinn(t_physics)
    dudt = torch.autograd.grad(u_p, t_physics, torch.ones_like(u_p), create_graph=True)[0]
    d2udt2 = torch.autograd.grad(dudt, t_physics, torch.ones_like(dudt), create_graph=True)[0]
    loss3 = torch.mean((d2udt2 + mu * dudt + k * u_p) ** 2)

    loss = loss1 + lambda1 * loss2 + lambda2 * loss3
    loss.backward()
    optimiser.step()

    u_pred = pinn(t_test).detach()
    mse = torch.mean((u_pred - u_exact) ** 2).item()

    if i % 100 == 0:
        with open("training_metrics.csv", mode="a", newline="") as file:
            writer = csv.writer(file)
            writer.writerow([i, loss.item(), loss1.item(), loss2.item(), loss3.item(), mse])

        print(f"[{i:5d}] Loss: {loss.item():.4e} | "
              f"Loss1 (u(0)-1)^2: {loss1.item():.2e} | "
              f"Loss2 (u'(0))^2: {loss2.item():.2e} | "
              f"Loss3 (PDE): {loss3.item():.2e} | "
              f"MSE vs exact: {mse:.2e}")

        # Gráfica y captura de imagen
        fig, ax = plt.subplots(figsize=(6, 2.5))
        ax.scatter(t_physics.detach()[:, 0], torch.zeros_like(t_physics)[:, 0],
                   s=20, lw=0, color="tab:green", alpha=0.6, label="Physics points")
        ax.scatter(t_boundary.detach()[:, 0], torch.zeros_like(t_boundary)[:, 0],
                   s=20, lw=0, color="tab:red", alpha=0.6, label="Boundary point")
        ax.plot(t_test[:, 0], u_exact[:, 0], label="Exact solution", color="tab:grey", alpha=0.6)
        ax.plot(t_test[:, 0], u_pred[:, 0], label="PINN solution", color="tab:green")
        ax.set_title(f"Step {i}")
        ax.legend()
        plt.tight_layout()

        buf = io.BytesIO()
        plt.savefig(buf, format='png')
        buf.seek(0)
        frames.append(Image.open(buf))
        plt.close()

# Guardar GIF
frames[0].save("pinn_training.gif", format='GIF',
               append_images=frames[1:], save_all=True,
               duration=120, loop=0)
# Out:
# [    0] Loss: 2.6888e+00 | Loss1 (u(0)-1)^2: 4.35e-01 | Loss2 (u'(0))^2: 2.74e-03 | Loss3 (PDE): 2.25e+04 | MSE vs exact: 2.50e-01
# [  100] Loss: 8.2271e-01 | Loss1 (u(0)-1)^2: 7.49e-01 | Loss2 (u'(0))^2: 5.42e-02 | Loss3 (PDE): 6.87e+02 | MSE vs exact: 1.29e-01
# [  200] Loss: 7.8464e-01 | Loss1 (u(0)-1)^2: 6.40e-01 | Loss2 (u'(0))^2: 1.50e-01 | Loss3 (PDE): 1.29e+03 | MSE vs exact: 1.31e-01
# [  300] Loss: 7.8047e-01 | Loss1 (u(0)-1)^2: 6.22e-01 | Loss2 (u'(0))^2: 1.85e-01 | Loss3 (PDE): 1.40e+03 | MSE vs exact: 1.32e-01
# [  400] Loss: 7.7633e-01 | Loss1 (u(0)-1)^2: 6.15e-01 | Loss2 (u'(0))^2: 2.11e-01 | Loss3 (PDE): 1.40e+03 | MSE vs exact: 1.31e-01
# [  500] Loss: 7.7200e-01 | Loss1 (u(0)-1)^2: 6.08e-01 | Loss2 (u'(0))^2: 2.44e-01 | Loss3 (PDE): 1.39e+03 | MSE vs exact: 1.31e-01
# [  600] Loss: 7.6769e-01 | Loss1 (u(0)-1)^2: 6.01e-01 | Loss2 (u'(0))^2: 2.81e-01 | Loss3 (PDE): 1.38e+03 | MSE vs exact: 1.30e-01
# [  700] Loss: 7.6355e-01 | Loss1 (u(0)-1)^2: 5.94e-01 | Loss2 (u'(0))^2: 3.24e-01 | Loss3 (PDE): 1.37e+03 | MSE vs exact: 1.30e-01
# [  800] Loss: 7.5970e-01 | Loss1 (u(0)-1)^2: 5.87e-01 | Loss2 (u'(0))^2: 3.69e-01 | Loss3 (PDE): 1.36e+03 | MSE vs exact: 1.29e-01
# [  900] Loss: 7.5616e-01 | Loss1 (u(0)-1)^2: 5.80e-01 | Loss2 (u'(0))^2: 4.13e-01 | Loss3 (PDE): 1.35e+03 | MSE vs exact: 1.29e-01
# [ 1000] Loss: 7.5285e-01 | Loss1 (u(0)-1)^2: 5.72e-01 | Loss2 (u'(0))^2: 4.51e-01 | Loss3 (PDE): 1.35e+03 | MSE vs exact: 1.29e-01
# [ 1100] Loss: 7.4959e-01 | Loss1 (u(0)-1)^2: 5.66e-01 | Loss2 (u'(0))^2: 4.76e-01 | Loss3 (PDE): 1.36e+03 | MSE vs exact: 1.28e-01
# [ 1200] Loss: 7.4621e-01 | Loss1 (u(0)-1)^2: 5.60e-01 | Loss2 (u'(0))^2: 4.85e-01 | Loss3 (PDE): 1.38e+03 | MSE vs exact: 1.28e-01
# [ 1300] Loss: 7.4268e-01 | Loss1 (u(0)-1)^2: 5.54e-01 | Loss2 (u'(0))^2: 4.82e-01 | Loss3 (PDE): 1.40e+03 | MSE vs exact: 1.28e-01
# [ 1400] Loss: 7.3912e-01 | Loss1 (u(0)-1)^2: 5.48e-01 | Loss2 (u'(0))^2: 4.71e-01 | Loss3 (PDE): 1.44e+03 | MSE vs exact: 1.28e-01
# [ 1500] Loss: 7.3568e-01 | Loss1 (u(0)-1)^2: 5.43e-01 | Loss2 (u'(0))^2: 4.57e-01 | Loss3 (PDE): 1.47e+03 | MSE vs exact: 1.28e-01
# [ 1600] Loss: 7.3241e-01 | Loss1 (u(0)-1)^2: 5.37e-01 | Loss2 (u'(0))^2: 4.41e-01 | Loss3 (PDE): 1.52e+03 | MSE vs exact: 1.29e-01
# [ 1700] Loss: 7.2921e-01 | Loss1 (u(0)-1)^2: 5.30e-01 | Loss2 (u'(0))^2: 4.26e-01 | Loss3 (PDE): 1.56e+03 | MSE vs exact: 1.29e-01
# [ 1800] Loss: 7.2579e-01 | Loss1 (u(0)-1)^2: 5.24e-01 | Loss2 (u'(0))^2: 4.12e-01 | Loss3 (PDE): 1.60e+03 | MSE vs exact: 1.29e-01
# [ 1900] Loss: 7.2170e-01 | Loss1 (u(0)-1)^2: 5.18e-01 | Loss2 (u'(0))^2: 4.01e-01 | Loss3 (PDE): 1.64e+03 | MSE vs exact: 1.29e-01
# [ 2000] Loss: 7.1630e-01 | Loss1 (u(0)-1)^2: 5.10e-01 | Loss2 (u'(0))^2: 3.90e-01 | Loss3 (PDE): 1.68e+03 | MSE vs exact: 1.29e-01
# [ 2100] Loss: 7.0855e-01 | Loss1 (u(0)-1)^2: 4.99e-01 | Loss2 (u'(0))^2: 3.78e-01 | Loss3 (PDE): 1.72e+03 | MSE vs exact: 1.30e-01
# [ 2200] Loss: 6.9677e-01 | Loss1 (u(0)-1)^2: 4.84e-01 | Loss2 (u'(0))^2: 3.61e-01 | Loss3 (PDE): 1.76e+03 | MSE vs exact: 1.30e-01
# [ 2300] Loss: 6.7847e-01 | Loss1 (u(0)-1)^2: 4.63e-01 | Loss2 (u'(0))^2: 3.34e-01 | Loss3 (PDE): 1.82e+03 | MSE vs exact: 1.30e-01
# [ 2400] Loss: 6.5031e-01 | Loss1 (u(0)-1)^2: 4.31e-01 | Loss2 (u'(0))^2: 2.92e-01 | Loss3 (PDE): 1.90e+03 | MSE vs exact: 1.30e-01
# [ 2500] Loss: 6.0553e-01 | Loss1 (u(0)-1)^2: 3.87e-01 | Loss2 (u'(0))^2: 2.25e-01 | Loss3 (PDE): 1.96e+03 | MSE vs exact: 1.27e-01
# [ 2600] Loss: 5.3092e-01 | Loss1 (u(0)-1)^2: 3.23e-01 | Loss2 (u'(0))^2: 1.31e-01 | Loss3 (PDE): 1.94e+03 | MSE vs exact: 1.19e-01
# [ 2700] Loss: 4.2277e-01 | Loss1 (u(0)-1)^2: 2.40e-01 | Loss2 (u'(0))^2: 5.56e-02 | Loss3 (PDE): 1.78e+03 | MSE vs exact: 1.04e-01
# [ 2800] Loss: 3.0981e-01 | Loss1 (u(0)-1)^2: 1.55e-01 | Loss2 (u'(0))^2: 2.08e-02 | Loss3 (PDE): 1.53e+03 | MSE vs exact: 8.83e-02
# [ 2900] Loss: 2.3742e-01 | Loss1 (u(0)-1)^2: 9.53e-02 | Loss2 (u'(0))^2: 7.83e-03 | Loss3 (PDE): 1.41e+03 | MSE vs exact: 7.78e-02
# [ 3000] Loss: 2.0910e-01 | Loss1 (u(0)-1)^2: 6.64e-02 | Loss2 (u'(0))^2: 5.24e-03 | Loss3 (PDE): 1.42e+03 | MSE vs exact: 7.37e-02
# [ 3100] Loss: 1.9606e-01 | Loss1 (u(0)-1)^2: 5.44e-02 | Loss2 (u'(0))^2: 1.66e-03 | Loss3 (PDE): 1.41e+03 | MSE vs exact: 7.25e-02
# [ 3200] Loss: 1.8687e-01 | Loss1 (u(0)-1)^2: 4.82e-02 | Loss2 (u'(0))^2: 9.56e-04 | Loss3 (PDE): 1.39e+03 | MSE vs exact: 7.20e-02
# [ 3300] Loss: 1.7949e-01 | Loss1 (u(0)-1)^2: 4.40e-02 | Loss2 (u'(0))^2: 4.54e-04 | Loss3 (PDE): 1.35e+03 | MSE vs exact: 7.15e-02
# [ 3400] Loss: 1.7253e-01 | Loss1 (u(0)-1)^2: 4.08e-02 | Loss2 (u'(0))^2: 3.90e-04 | Loss3 (PDE): 1.32e+03 | MSE vs exact: 7.09e-02
# [ 3500] Loss: 1.6404e-01 | Loss1 (u(0)-1)^2: 3.79e-02 | Loss2 (u'(0))^2: 2.18e-04 | Loss3 (PDE): 1.26e+03 | MSE vs exact: 7.01e-02
# [ 3600] Loss: 1.5214e-01 | Loss1 (u(0)-1)^2: 3.42e-02 | Loss2 (u'(0))^2: 5.85e-04 | Loss3 (PDE): 1.18e+03 | MSE vs exact: 6.84e-02
# [ 3700] Loss: 1.3828e-01 | Loss1 (u(0)-1)^2: 2.92e-02 | Loss2 (u'(0))^2: 6.67e-05 | Loss3 (PDE): 1.09e+03 | MSE vs exact: 6.58e-02
# [ 3800] Loss: 1.2803e-01 | Loss1 (u(0)-1)^2: 2.41e-02 | Loss2 (u'(0))^2: 1.43e-05 | Loss3 (PDE): 1.04e+03 | MSE vs exact: 6.31e-02
# [ 3900] Loss: 1.2198e-01 | Loss1 (u(0)-1)^2: 2.02e-02 | Loss2 (u'(0))^2: 5.08e-06 | Loss3 (PDE): 1.02e+03 | MSE vs exact: 6.08e-02
# [ 4000] Loss: 1.1815e-01 | Loss1 (u(0)-1)^2: 1.82e-02 | Loss2 (u'(0))^2: 1.45e-03 | Loss3 (PDE): 9.98e+02 | MSE vs exact: 5.89e-02
# [ 4100] Loss: 1.1536e-01 | Loss1 (u(0)-1)^2: 1.65e-02 | Loss2 (u'(0))^2: 7.86e-06 | Loss3 (PDE): 9.88e+02 | MSE vs exact: 5.74e-02
# [ 4200] Loss: 1.1337e-01 | Loss1 (u(0)-1)^2: 1.56e-02 | Loss2 (u'(0))^2: 1.95e-05 | Loss3 (PDE): 9.77e+02 | MSE vs exact: 5.62e-02
# [ 4300] Loss: 1.1165e-01 | Loss1 (u(0)-1)^2: 1.50e-02 | Loss2 (u'(0))^2: 1.36e-05 | Loss3 (PDE): 9.67e+02 | MSE vs exact: 5.52e-02
# [ 4400] Loss: 1.0989e-01 | Loss1 (u(0)-1)^2: 1.45e-02 | Loss2 (u'(0))^2: 4.05e-05 | Loss3 (PDE): 9.54e+02 | MSE vs exact: 5.44e-02
# [ 4500] Loss: 1.0799e-01 | Loss1 (u(0)-1)^2: 1.40e-02 | Loss2 (u'(0))^2: 3.28e-05 | Loss3 (PDE): 9.40e+02 | MSE vs exact: 5.37e-02
# [ 4600] Loss: 1.0584e-01 | Loss1 (u(0)-1)^2: 1.35e-02 | Loss2 (u'(0))^2: 5.19e-05 | Loss3 (PDE): 9.23e+02 | MSE vs exact: 5.28e-02
# [ 4700] Loss: 1.0337e-01 | Loss1 (u(0)-1)^2: 1.29e-02 | Loss2 (u'(0))^2: 5.66e-05 | Loss3 (PDE): 9.04e+02 | MSE vs exact: 5.19e-02
# [ 4800] Loss: 1.0041e-01 | Loss1 (u(0)-1)^2: 1.22e-02 | Loss2 (u'(0))^2: 5.59e-05 | Loss3 (PDE): 8.82e+02 | MSE vs exact: 5.08e-02
# [ 4900] Loss: 9.6832e-02 | Loss1 (u(0)-1)^2: 1.14e-02 | Loss2 (u'(0))^2: 7.11e-05 | Loss3 (PDE): 8.54e+02 | MSE vs exact: 4.94e-02
# [ 5000] Loss: 9.2403e-02 | Loss1 (u(0)-1)^2: 1.05e-02 | Loss2 (u'(0))^2: 5.79e-05 | Loss3 (PDE): 8.19e+02 | MSE vs exact: 4.78e-02
# [ 5100] Loss: 8.6940e-02 | Loss1 (u(0)-1)^2: 9.37e-03 | Loss2 (u'(0))^2: 8.56e-05 | Loss3 (PDE): 7.76e+02 | MSE vs exact: 4.57e-02
# [ 5200] Loss: 8.0540e-02 | Loss1 (u(0)-1)^2: 8.11e-03 | Loss2 (u'(0))^2: 4.89e-05 | Loss3 (PDE): 7.24e+02 | MSE vs exact: 4.32e-02
# [ 5300] Loss: 7.3418e-02 | Loss1 (u(0)-1)^2: 6.79e-03 | Loss2 (u'(0))^2: 1.09e-05 | Loss3 (PDE): 6.66e+02 | MSE vs exact: 4.04e-02
# [ 5400] Loss: 6.6366e-02 | Loss1 (u(0)-1)^2: 5.61e-03 | Loss2 (u'(0))^2: 3.26e-05 | Loss3 (PDE): 6.08e+02 | MSE vs exact: 3.75e-02
# [ 5500] Loss: 6.0063e-02 | Loss1 (u(0)-1)^2: 4.59e-03 | Loss2 (u'(0))^2: 1.14e-04 | Loss3 (PDE): 5.55e+02 | MSE vs exact: 3.48e-02
# [ 5600] Loss: 5.5255e-02 | Loss1 (u(0)-1)^2: 3.89e-03 | Loss2 (u'(0))^2: 1.37e-05 | Loss3 (PDE): 5.14e+02 | MSE vs exact: 3.26e-02
# [ 5700] Loss: 5.1832e-02 | Loss1 (u(0)-1)^2: 3.32e-03 | Loss2 (u'(0))^2: 3.70e-05 | Loss3 (PDE): 4.85e+02 | MSE vs exact: 3.07e-02
# [ 5800] Loss: 4.9125e-02 | Loss1 (u(0)-1)^2: 2.94e-03 | Loss2 (u'(0))^2: 8.25e-06 | Loss3 (PDE): 4.62e+02 | MSE vs exact: 2.92e-02
# [ 5900] Loss: 4.6637e-02 | Loss1 (u(0)-1)^2: 2.60e-03 | Loss2 (u'(0))^2: 5.02e-07 | Loss3 (PDE): 4.40e+02 | MSE vs exact: 2.79e-02
# [ 6000] Loss: 4.4148e-02 | Loss1 (u(0)-1)^2: 2.31e-03 | Loss2 (u'(0))^2: 5.07e-06 | Loss3 (PDE): 4.18e+02 | MSE vs exact: 2.66e-02
# [ 6100] Loss: 4.1634e-02 | Loss1 (u(0)-1)^2: 2.03e-03 | Loss2 (u'(0))^2: 7.51e-06 | Loss3 (PDE): 3.96e+02 | MSE vs exact: 2.53e-02
# [ 6200] Loss: 3.9058e-02 | Loss1 (u(0)-1)^2: 1.76e-03 | Loss2 (u'(0))^2: 3.55e-06 | Loss3 (PDE): 3.73e+02 | MSE vs exact: 2.40e-02
# [ 6300] Loss: 3.6590e-02 | Loss1 (u(0)-1)^2: 1.52e-03 | Loss2 (u'(0))^2: 9.87e-06 | Loss3 (PDE): 3.51e+02 | MSE vs exact: 2.28e-02
# [ 6400] Loss: 3.4445e-02 | Loss1 (u(0)-1)^2: 1.33e-03 | Loss2 (u'(0))^2: 2.64e-06 | Loss3 (PDE): 3.31e+02 | MSE vs exact: 2.17e-02
# [ 6500] Loss: 3.2748e-02 | Loss1 (u(0)-1)^2: 1.19e-03 | Loss2 (u'(0))^2: 2.02e-06 | Loss3 (PDE): 3.16e+02 | MSE vs exact: 2.06e-02
# [ 6600] Loss: 3.1356e-02 | Loss1 (u(0)-1)^2: 1.08e-03 | Loss2 (u'(0))^2: 2.18e-06 | Loss3 (PDE): 3.03e+02 | MSE vs exact: 1.98e-02
# [ 6700] Loss: 3.0100e-02 | Loss1 (u(0)-1)^2: 1.01e-03 | Loss2 (u'(0))^2: 2.11e-06 | Loss3 (PDE): 2.91e+02 | MSE vs exact: 1.91e-02
# [ 6800] Loss: 2.8939e-02 | Loss1 (u(0)-1)^2: 9.49e-04 | Loss2 (u'(0))^2: 2.04e-04 | Loss3 (PDE): 2.80e+02 | MSE vs exact: 1.84e-02
# [ 6900] Loss: 2.7756e-02 | Loss1 (u(0)-1)^2: 8.71e-04 | Loss2 (u'(0))^2: 1.56e-06 | Loss3 (PDE): 2.69e+02 | MSE vs exact: 1.77e-02
# [ 7000] Loss: 2.6612e-02 | Loss1 (u(0)-1)^2: 7.94e-04 | Loss2 (u'(0))^2: 1.27e-04 | Loss3 (PDE): 2.58e+02 | MSE vs exact: 1.70e-02
# [ 7100] Loss: 2.5451e-02 | Loss1 (u(0)-1)^2: 7.29e-04 | Loss2 (u'(0))^2: 1.07e-06 | Loss3 (PDE): 2.47e+02 | MSE vs exact: 1.63e-02
# [ 7200] Loss: 2.4280e-02 | Loss1 (u(0)-1)^2: 6.62e-04 | Loss2 (u'(0))^2: 1.47e-04 | Loss3 (PDE): 2.36e+02 | MSE vs exact: 1.56e-02
# [ 7300] Loss: 2.3066e-02 | Loss1 (u(0)-1)^2: 6.05e-04 | Loss2 (u'(0))^2: 1.13e-06 | Loss3 (PDE): 2.25e+02 | MSE vs exact: 1.49e-02
# [ 7400] Loss: 2.1798e-02 | Loss1 (u(0)-1)^2: 5.56e-04 | Loss2 (u'(0))^2: 1.66e-04 | Loss3 (PDE): 2.12e+02 | MSE vs exact: 1.41e-02
# [ 7500] Loss: 2.0272e-02 | Loss1 (u(0)-1)^2: 4.99e-04 | Loss2 (u'(0))^2: 4.55e-07 | Loss3 (PDE): 1.98e+02 | MSE vs exact: 1.33e-02
# [ 7600] Loss: 1.8017e-02 | Loss1 (u(0)-1)^2: 4.41e-04 | Loss2 (u'(0))^2: 3.36e-05 | Loss3 (PDE): 1.76e+02 | MSE vs exact: 1.20e-02
# [ 7700] Loss: 1.4845e-02 | Loss1 (u(0)-1)^2: 3.61e-04 | Loss2 (u'(0))^2: 1.34e-07 | Loss3 (PDE): 1.45e+02 | MSE vs exact: 1.01e-02
# [ 7800] Loss: 1.2077e-02 | Loss1 (u(0)-1)^2: 2.62e-04 | Loss2 (u'(0))^2: 7.26e-04 | Loss3 (PDE): 1.17e+02 | MSE vs exact: 8.06e-03
# [ 7900] Loss: 1.0281e-02 | Loss1 (u(0)-1)^2: 1.93e-04 | Loss2 (u'(0))^2: 1.40e-07 | Loss3 (PDE): 1.01e+02 | MSE vs exact: 6.49e-03
# [ 8000] Loss: 9.5255e-03 | Loss1 (u(0)-1)^2: 1.41e-04 | Loss2 (u'(0))^2: 4.27e-08 | Loss3 (PDE): 9.38e+01 | MSE vs exact: 5.44e-03
# [ 8100] Loss: 9.2582e-03 | Loss1 (u(0)-1)^2: 1.13e-04 | Loss2 (u'(0))^2: 1.13e-06 | Loss3 (PDE): 9.15e+01 | MSE vs exact: 4.86e-03
# [ 8200] Loss: 9.1520e-03 | Loss1 (u(0)-1)^2: 9.86e-05 | Loss2 (u'(0))^2: 2.60e-10 | Loss3 (PDE): 9.05e+01 | MSE vs exact: 4.57e-03
# [ 8300] Loss: 9.1122e-03 | Loss1 (u(0)-1)^2: 9.30e-05 | Loss2 (u'(0))^2: 1.50e-04 | Loss3 (PDE): 9.00e+01 | MSE vs exact: 4.42e-03
# [ 8400] Loss: 9.0289e-03 | Loss1 (u(0)-1)^2: 8.86e-05 | Loss2 (u'(0))^2: 5.92e-09 | Loss3 (PDE): 8.94e+01 | MSE vs exact: 4.33e-03
# [ 8500] Loss: 8.9715e-03 | Loss1 (u(0)-1)^2: 8.70e-05 | Loss2 (u'(0))^2: 5.07e-08 | Loss3 (PDE): 8.88e+01 | MSE vs exact: 4.28e-03
# [ 8600] Loss: 8.9143e-03 | Loss1 (u(0)-1)^2: 8.61e-05 | Loss2 (u'(0))^2: 9.06e-07 | Loss3 (PDE): 8.83e+01 | MSE vs exact: 4.25e-03
# [ 8700] Loss: 8.8562e-03 | Loss1 (u(0)-1)^2: 8.55e-05 | Loss2 (u'(0))^2: 2.66e-07 | Loss3 (PDE): 8.77e+01 | MSE vs exact: 4.21e-03
# [ 8800] Loss: 8.7989e-03 | Loss1 (u(0)-1)^2: 8.50e-05 | Loss2 (u'(0))^2: 1.04e-07 | Loss3 (PDE): 8.71e+01 | MSE vs exact: 4.18e-03
# [ 8900] Loss: 8.7416e-03 | Loss1 (u(0)-1)^2: 8.45e-05 | Loss2 (u'(0))^2: 5.70e-09 | Loss3 (PDE): 8.66e+01 | MSE vs exact: 4.15e-03
# [ 9000] Loss: 8.6861e-03 | Loss1 (u(0)-1)^2: 8.41e-05 | Loss2 (u'(0))^2: 2.27e-06 | Loss3 (PDE): 8.60e+01 | MSE vs exact: 4.12e-03
# [ 9100] Loss: 8.6312e-03 | Loss1 (u(0)-1)^2: 8.37e-05 | Loss2 (u'(0))^2: 1.13e-08 | Loss3 (PDE): 8.55e+01 | MSE vs exact: 4.09e-03
# [ 9200] Loss: 8.5854e-03 | Loss1 (u(0)-1)^2: 8.34e-05 | Loss2 (u'(0))^2: 4.85e-05 | Loss3 (PDE): 8.50e+01 | MSE vs exact: 4.06e-03
# [ 9300] Loss: 8.5251e-03 | Loss1 (u(0)-1)^2: 8.27e-05 | Loss2 (u'(0))^2: 4.55e-08 | Loss3 (PDE): 8.44e+01 | MSE vs exact: 4.03e-03
# [ 9400] Loss: 8.4740e-03 | Loss1 (u(0)-1)^2: 8.21e-05 | Loss2 (u'(0))^2: 2.92e-08 | Loss3 (PDE): 8.39e+01 | MSE vs exact: 3.99e-03
# [ 9500] Loss: 8.4247e-03 | Loss1 (u(0)-1)^2: 8.15e-05 | Loss2 (u'(0))^2: 1.25e-06 | Loss3 (PDE): 8.34e+01 | MSE vs exact: 3.96e-03
# [ 9600] Loss: 8.3763e-03 | Loss1 (u(0)-1)^2: 8.09e-05 | Loss2 (u'(0))^2: 6.22e-09 | Loss3 (PDE): 8.30e+01 | MSE vs exact: 3.93e-03
# [ 9700] Loss: 8.3405e-03 | Loss1 (u(0)-1)^2: 8.03e-05 | Loss2 (u'(0))^2: 7.00e-05 | Loss3 (PDE): 8.25e+01 | MSE vs exact: 3.90e-03
# [ 9800] Loss: 8.2813e-03 | Loss1 (u(0)-1)^2: 7.96e-05 | Loss2 (u'(0))^2: 9.22e-09 | Loss3 (PDE): 8.20e+01 | MSE vs exact: 3.86e-03
# [ 9900] Loss: 8.4379e-03 | Loss1 (u(0)-1)^2: 7.90e-05 | Loss2 (u'(0))^2: 1.15e-03 | Loss3 (PDE): 8.24e+01 | MSE vs exact: 3.84e-03
# [10000] Loss: 8.1869e-03 | Loss1 (u(0)-1)^2: 7.83e-05 | Loss2 (u'(0))^2: 1.61e-09 | Loss3 (PDE): 8.11e+01 | MSE vs exact: 3.80e-03

# %%
import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt
import csv
from PIL import Image
import io

# Lista para guardar imágenes del entrenamiento
frames = []

# ============================================
# SOLUCIÓN EXACTA DEL OSCILADOR AMORTIGUADO
# ============================================
def exact_solution(d, w0, t):
    assert d < w0
    w = np.sqrt(w0**2 - d**2)
    phi = np.arctan(-d / w)
    A = 1 / (2 * np.cos(phi))
    cos = torch.cos(phi + w * t)
    exp = torch.exp(-d * t)
    u = exp * 2 * A * cos
    return u

# ============================================
# DEFINICIÓN DE LA RED NEURONAL TOTALMENTE CONECTADA
# ============================================
class FCN(nn.Module):
    def __init__(self, N_INPUT, N_OUTPUT, N_HIDDEN, N_LAYERS):
        super().__init__()
        activation = nn.Tanh
        self.fcs = nn.Sequential(nn.Linear(N_INPUT, N_HIDDEN), activation())
        self.fch = nn.Sequential(*[
            nn.Sequential(nn.Linear(N_HIDDEN, N_HIDDEN), activation())
            for _ in range(N_LAYERS - 1)
        ])
        self.fce = nn.Linear(N_HIDDEN, N_OUTPUT)

    def forward(self, x):
        x = self.fcs(x)
        x = self.fch(x)
        x = self.fce(x)
        return x

# ============================================
# PARÁMETROS DEL SISTEMA Y DATOS DE ENTRENAMIENTO
# ============================================
torch.manual_seed(123)
d, w0 = 2, 20

# Datos sintéticos para entrenamiento (supervisado)
t_train = torch.linspace(0, 1, 30).view(-1, 1)  # mismos puntos que t_physics antes
u_train = exact_solution(d, w0, t_train)

# Datos para evaluación
t_test = torch.linspace(0, 1, 300).view(-1, 1)
u_exact = exact_solution(d, w0, t_test)

# ============================================
# INICIALIZACIÓN DE MODELO Y OPTIMIZADOR
# ============================================
pinn = FCN(1, 1, 20, 3)
optimiser = torch.optim.Adam(pinn.parameters(), lr=1e-3)

# ============================================
# ARCHIVO PARA GUARDAR MÉTRICAS
# ============================================
with open("training_metrics.csv", mode="w", newline="") as file:
    writer = csv.writer(file)
    writer.writerow(["Iteration", "Loss", "MSE"])

# ============================================
# BUCLE DE ENTRENAMIENTO SUPERVISADO DIRECTO
# ============================================
for i in range(10001):
    optimiser.zero_grad()

    u_pred = pinn(t_train)
    loss = torch.mean((u_pred - u_train) ** 2)

    loss.backward()
    optimiser.step()

    # Evaluación en test
    u_pred_test = pinn(t_test).detach()
    mse = torch.mean((u_pred_test - u_exact) ** 2).item()

    if i % 100 == 0:
        with open("training_metrics.csv", mode="a", newline="") as file:
            writer = csv.writer(file)
            writer.writerow([i, loss.item(), mse])

        print(f"[{i:5d}] Loss (train): {loss.item():.4e} | MSE (test): {mse:.4e}")

        # Gráfica y captura de imagen
        fig, ax = plt.subplots(figsize=(6, 2.5))
        ax.scatter(t_train[:, 0], u_train[:, 0],
                   s=20, lw=0, color="tab:blue", alpha=0.6, label="Training data")
        ax.plot(t_test[:, 0], u_exact[:, 0], label="Exact solution", color="tab:grey", alpha=0.6)
        ax.plot(t_test[:, 0], u_pred_test[:, 0], label="NN prediction", color="tab:green")
        ax.set_title(f"Step {i}")
        ax.legend()
        plt.tight_layout()

        buf = io.BytesIO()
        plt.savefig(buf, format='png')
        buf.seek(0)
        frames.append(Image.open(buf))
        plt.close()

# Guardar GIF
frames[0].save("nn_training.gif", format='GIF',
               append_images=frames[1:], save_all=True,
               duration=120, loop=0)
# Out:
# [    0] Loss (train): 1.4892e-01 | MSE (test): 1.3522e-01
# [  100] Loss (train): 1.3530e-01 | MSE (test): 1.2768e-01
# [  200] Loss (train): 1.2793e-01 | MSE (test): 1.2319e-01
# [  300] Loss (train): 9.1229e-02 | MSE (test): 9.1559e-02
# [  400] Loss (train): 3.7796e-02 | MSE (test): 3.7955e-02
# [  500] Loss (train): 2.5178e-02 | MSE (test): 2.5665e-02
# [  600] Loss (train): 1.5872e-02 | MSE (test): 1.6518e-02
# [  700] Loss (train): 1.0740e-02 | MSE (test): 1.0849e-02
# [  800] Loss (train): 6.0601e-03 | MSE (test): 6.0233e-03
# [  900] Loss (train): 3.7521e-03 | MSE (test): 3.4570e-03
# [ 1000] Loss (train): 3.1925e-03 | MSE (test): 2.7110e-03
# [ 1100] Loss (train): 3.0286e-03 | MSE (test): 2.5005e-03
# [ 1200] Loss (train): 2.9198e-03 | MSE (test): 2.3905e-03
# [ 1300] Loss (train): 2.8206e-03 | MSE (test): 2.3309e-03
# [ 1400] Loss (train): 2.7337e-03 | MSE (test): 2.2696e-03
# [ 1500] Loss (train): 2.6757e-03 | MSE (test): 2.2111e-03
# [ 1600] Loss (train): 2.5789e-03 | MSE (test): 2.1629e-03
# [ 1700] Loss (train): 2.5061e-03 | MSE (test): 2.1099e-03
# [ 1800] Loss (train): 2.4351e-03 | MSE (test): 2.0530e-03
# [ 1900] Loss (train): 2.3590e-03 | MSE (test): 1.9973e-03
# [ 2000] Loss (train): 2.2811e-03 | MSE (test): 1.9345e-03
# [ 2100] Loss (train): 2.1991e-03 | MSE (test): 1.8685e-03
# [ 2200] Loss (train): 2.1098e-03 | MSE (test): 1.7897e-03
# [ 2300] Loss (train): 2.0151e-03 | MSE (test): 1.7072e-03
# [ 2400] Loss (train): 1.9110e-03 | MSE (test): 1.6166e-03
# [ 2500] Loss (train): 1.8077e-03 | MSE (test): 1.5139e-03
# [ 2600] Loss (train): 1.6732e-03 | MSE (test): 1.4054e-03
# [ 2700] Loss (train): 1.5397e-03 | MSE (test): 1.2958e-03
# [ 2800] Loss (train): 1.3869e-03 | MSE (test): 1.1503e-03
# [ 2900] Loss (train): 1.3721e-03 | MSE (test): 1.1808e-03
# [ 3000] Loss (train): 1.0473e-03 | MSE (test): 8.4852e-04
# [ 3100] Loss (train): 8.6995e-04 | MSE (test): 6.9223e-04
# [ 3200] Loss (train): 7.0553e-04 | MSE (test): 5.5225e-04
# [ 3300] Loss (train): 5.6681e-04 | MSE (test): 4.3329e-04
# [ 3400] Loss (train): 4.6115e-04 | MSE (test): 3.4780e-04
# [ 3500] Loss (train): 3.8555e-04 | MSE (test): 2.9087e-04
# [ 3600] Loss (train): 3.3120e-04 | MSE (test): 2.6391e-04
# [ 3700] Loss (train): 2.9026e-04 | MSE (test): 2.2401e-04
# [ 3800] Loss (train): 2.5737e-04 | MSE (test): 2.0211e-04
# [ 3900] Loss (train): 2.3207e-04 | MSE (test): 1.8658e-04
# [ 4000] Loss (train): 2.0894e-04 | MSE (test): 1.7004e-04
# [ 4100] Loss (train): 1.8937e-04 | MSE (test): 1.5691e-04
# [ 4200] Loss (train): 1.7532e-04 | MSE (test): 1.4679e-04
# [ 4300] Loss (train): 1.5882e-04 | MSE (test): 1.3615e-04
# [ 4400] Loss (train): 1.4699e-04 | MSE (test): 1.2980e-04
# [ 4500] Loss (train): 1.3611e-04 | MSE (test): 1.2058e-04
# [ 4600] Loss (train): 1.2701e-04 | MSE (test): 1.1400e-04
# [ 4700] Loss (train): 1.6754e-04 | MSE (test): 1.4153e-04
# [ 4800] Loss (train): 1.1200e-04 | MSE (test): 1.0334e-04
# [ 4900] Loss (train): 1.0559e-04 | MSE (test): 9.8583e-05
# [ 5000] Loss (train): 1.0028e-04 | MSE (test): 9.4739e-05
# [ 5100] Loss (train): 9.5196e-05 | MSE (test): 9.1106e-05
# [ 5200] Loss (train): 2.2844e-04 | MSE (test): 1.1750e-04
# [ 5300] Loss (train): 8.6710e-05 | MSE (test): 8.4809e-05
# [ 5400] Loss (train): 8.2972e-05 | MSE (test): 8.1990e-05
# [ 5500] Loss (train): 3.8576e-04 | MSE (test): 1.8109e-04
# [ 5600] Loss (train): 7.6658e-05 | MSE (test): 7.7243e-05
# [ 5700] Loss (train): 7.3865e-05 | MSE (test): 7.5055e-05
# [ 5800] Loss (train): 7.1162e-05 | MSE (test): 7.2931e-05
# [ 5900] Loss (train): 7.0255e-05 | MSE (test): 7.1107e-05
# [ 6000] Loss (train): 6.6457e-05 | MSE (test): 6.9281e-05
# [ 6100] Loss (train): 6.4244e-05 | MSE (test): 6.7507e-05
# [ 6200] Loss (train): 6.2749e-05 | MSE (test): 6.6024e-05
# [ 6300] Loss (train): 6.0428e-05 | MSE (test): 6.4506e-05
# [ 6400] Loss (train): 5.8578e-05 | MSE (test): 6.2988e-05
# [ 6500] Loss (train): 1.3911e-04 | MSE (test): 1.2410e-04
# [ 6600] Loss (train): 5.5295e-05 | MSE (test): 6.0400e-05
# [ 6700] Loss (train): 5.3738e-05 | MSE (test): 5.9099e-05
# [ 6800] Loss (train): 5.2187e-05 | MSE (test): 5.7812e-05
# [ 6900] Loss (train): 5.5989e-05 | MSE (test): 5.8847e-05
# [ 7000] Loss (train): 4.9363e-05 | MSE (test): 5.5558e-05
# [ 7100] Loss (train): 4.7974e-05 | MSE (test): 5.4384e-05
# [ 7200] Loss (train): 4.7436e-05 | MSE (test): 5.6948e-05
# [ 7300] Loss (train): 4.5429e-05 | MSE (test): 5.2347e-05
# [ 7400] Loss (train): 4.4169e-05 | MSE (test): 5.1274e-05
# [ 7500] Loss (train): 9.8568e-05 | MSE (test): 8.3542e-05
# [ 7600] Loss (train): 4.1778e-05 | MSE (test): 4.9338e-05
# [ 7700] Loss (train): 4.0590e-05 | MSE (test): 4.8336e-05
# [ 7800] Loss (train): 3.9715e-05 | MSE (test): 4.7620e-05
# [ 7900] Loss (train): 3.8348e-05 | MSE (test): 4.6504e-05
# [ 8000] Loss (train): 4.0638e-04 | MSE (test): 2.6118e-04
# [ 8100] Loss (train): 3.6178e-05 | MSE (test): 4.4743e-05
# [ 8200] Loss (train): 3.5087e-05 | MSE (test): 4.3793e-05
# [ 8300] Loss (train): 4.0126e-05 | MSE (test): 4.4364e-05
# [ 8400] Loss (train): 3.3024e-05 | MSE (test): 4.2086e-05
# [ 8500] Loss (train): 3.1984e-05 | MSE (test): 4.1187e-05
# [ 8600] Loss (train): 3.1431e-05 | MSE (test): 4.0398e-05
# [ 8700] Loss (train): 2.9957e-05 | MSE (test): 3.9488e-05
# [ 8800] Loss (train): 3.8794e-05 | MSE (test): 6.7781e-05
# [ 8900] Loss (train): 2.7968e-05 | MSE (test): 3.7776e-05
# [ 9000] Loss (train): 2.6965e-05 | MSE (test): 3.6919e-05
# [ 9100] Loss (train): 2.6899e-05 | MSE (test): 3.6220e-05
# [ 9200] Loss (train): 2.5031e-05 | MSE (test): 3.5253e-05
# [ 9300] Loss (train): 4.0997e-04 | MSE (test): 5.4902e-04
# [ 9400] Loss (train): 2.3176e-05 | MSE (test): 3.3696e-05
# [ 9500] Loss (train): 2.2253e-05 | MSE (test): 3.2811e-05
# [ 9600] Loss (train): 2.1688e-05 | MSE (test): 3.2732e-05
# [ 9700] Loss (train): 2.0478e-05 | MSE (test): 3.1326e-05
# [ 9800] Loss (train): 1.9595e-05 | MSE (test): 3.0432e-05
# [ 9900] Loss (train): 2.6313e-05 | MSE (test): 4.3442e-05
# [10000] Loss (train): 1.7903e-05 | MSE (test): 2.8919e-05

# %%
import matplotlib.pyplot as plt
import csv

# Listas para almacenar los datos
iterations = []
losses = []
mses = []

# Leer el archivo CSV
with open("training_metrics.csv", mode="r") as file:
    reader = csv.DictReader(file)
    for row in reader:
        iterations.append(int(row["Iteration"]))
        losses.append(float(row["Loss"]))
        mses.append(float(row["MSE"]))

# Crear la figura
plt.figure(figsize=(8, 4))

# Graficar el Loss y el MSE
plt.plot(iterations, losses, label="Loss (train)", color="tab:blue")
plt.plot(iterations, mses, label="MSE (test)", color="tab:orange")
plt.xlabel("Iteración")
plt.ylabel("Error")
plt.title("Evolución del error durante el entrenamiento")
plt.legend()
plt.grid(True)
plt.tight_layout()

# Mostrar o guardar la gráfica
plt.savefig("training_error_plot.png")
plt.show()

# %%
import torch
import torch.nn as nn

# Red definida como en tu código
class FCN(nn.Module):
    def __init__(self, N_INPUT, N_OUTPUT, N_HIDDEN, N_LAYERS):
        super().__init__()
        activation = nn.Tanh
        self.fcs = nn.Sequential(nn.Linear(N_INPUT, N_HIDDEN), activation())
        self.fch = nn.Sequential(*[
            nn.Sequential(nn.Linear(N_HIDDEN, N_HIDDEN), activation())
            for _ in range(N_LAYERS - 1)
        ])
        self.fce = nn.Linear(N_HIDDEN, N_OUTPUT)

    def forward(self, x):
        x = self.fcs(x)
        x = self.fch(x)
        x = self.fce(x)
        return x

# Instancia del modelo
model = FCN(1, 1, 30, 2)

# Cálculo del número de parámetros
total_params = sum(p.numel() for p in model.parameters())
trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)

print(f"Total de parámetros: {total_params}")
print(f"Parámetros entrenables: {trainable_params}")
# Out:
# Total de parámetros: 1021
# Parámetros entrenables: 1021

# %%
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
import networkx as nx

# Definir la red neuronal
class FCN(nn.Module):
    def __init__(self, N_INPUT, N_OUTPUT, N_HIDDEN, N_LAYERS):
        super().__init__()
        activation = nn.Tanh
        self.fcs = nn.Sequential(nn.Linear(N_INPUT, N_HIDDEN), activation())
        self.fch = nn.Sequential(*[
            nn.Sequential(nn.Linear(N_HIDDEN, N_HIDDEN), activation())
            for _ in range(N_LAYERS - 1)
        ])
        self.fce = nn.Linear(N_HIDDEN, N_OUTPUT)

    def forward(self, x):
        x = self.fcs(x)
        x = self.fch(x)
        x = self.fce(x)
        return x

# Crear red
model = FCN(1, 1, 5, 2)

# Contar parámetros
total_params = sum(p.numel() for p in model.parameters())
print(f"Total de parámetros entrenables: {total_params}")

# Crear grafo para visualizar arquitectura
G = nx.DiGraph()
layer_sizes = [1, 5, 5, 1]
positions = {}
node_id = 0
layer_nodes = []

# Posicionar nodos
for x, size in enumerate(layer_sizes):
    layer = []
    for y in range(size):
        positions[node_id] = (x, -y)
        layer.append(node_id)
        node_id += 1
    layer_nodes.append(layer)

# Conectar nodos
for i in range(len(layer_nodes) - 1):
    for a in layer_nodes[i]:
        for b in layer_nodes[i + 1]:
            G.add_edge(a, b)

# Graficar
plt.figure(figsize=(8, 5))
nx.draw(G, pos=positions, node_color='skyblue', with_labels=False, node_size=300, edge_color='gray')
plt.title(f"Arquitectura de la red ({total_params} parámetros)")
plt.axis('off')
plt.tight_layout()
plt.show()
# Out:
# Total de parámetros entrenables: 46
# <ipython-input-35-8bd052087630>:58: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
import networkx as nx

# ======================================
# DEFINICIÓN DE LA RED NEURONAL
# ======================================
class FCN(nn.Module):
    def __init__(self, N_INPUT, N_OUTPUT, N_HIDDEN, N_LAYERS):
        super().__init__()
        activation = nn.Tanh
        self.fcs = nn.Sequential(nn.Linear(N_INPUT, N_HIDDEN), activation())
        self.fch = nn.Sequential(*[
            nn.Sequential(nn.Linear(N_HIDDEN, N_HIDDEN), activation())
            for _ in range(N_LAYERS - 1)
        ])
        self.fce = nn.Linear(N_HIDDEN, N_OUTPUT)

    def forward(self, x):
        x = self.fcs(x)
        x = self.fch(x)
        x = self.fce(x)
        return x

# ======================================
# CREACIÓN DE LA RED
# ======================================
model = FCN(N_INPUT=1, N_OUTPUT=1, N_HIDDEN=5, N_LAYERS=2)

print("=======================================")
print("CÁLCULO PASO A PASO DE LOS PARÁMETROS:")
print("=======================================")

total_params = 0
layer_idx = 0

for name, param in model.named_parameters():
    if param.requires_grad:
        shape = param.shape
        num_params = param.numel()
        total_params += num_params
        print(f"[{layer_idx}] {name:<30} shape={tuple(shape)} \t=> {num_params} parámetros")
        layer_idx += 1

print("=======================================")
print(f"TOTAL DE PARÁMETROS ENTRENABLES: {total_params}")
print("=======================================")

# ======================================
# VISUALIZACIÓN DE LA ARQUITECTURA
# ======================================
# Tamaños por capa: entrada, capas ocultas, salida
layer_sizes = [1, 5, 5, 1]

G = nx.DiGraph()
positions = {}
node_id = 0
layer_nodes = []

# Posicionar nodos (para dibujo)
for x, size in enumerate(layer_sizes):
    layer = []
    for y in range(size):
        positions[node_id] = (x, -y)
        layer.append(node_id)
        node_id += 1
    layer_nodes.append(layer)

# Conectar nodos capa a capa
for i in range(len(layer_nodes) - 1):
    for a in layer_nodes[i]:
        for b in layer_nodes[i + 1]:
            G.add_edge(a, b)

# Graficar
plt.figure(figsize=(8, 5))
nx.draw(G, pos=positions,
        node_color='skyblue',
        with_labels=False,
        node_size=500,
        edge_color='gray')
plt.title(f"Arquitectura de la red ({total_params} parámetros)")
plt.axis('off')
plt.tight_layout()
plt.show()
# Out:
# =======================================
# CÁLCULO PASO A PASO DE LOS PARÁMETROS:
# =======================================
# [0] fcs.0.weight                   shape=(5, 1) 	=> 5 parámetros
# [1] fcs.0.bias                     shape=(5,) 	=> 5 parámetros
# [2] fch.0.0.weight                 shape=(5, 5) 	=> 25 parámetros
# [3] fch.0.0.bias                   shape=(5,) 	=> 5 parámetros
# [4] fce.weight                     shape=(1, 5) 	=> 5 parámetros
# [5] fce.bias                       shape=(1,) 	=> 1 parámetros
# =======================================
# TOTAL DE PARÁMETROS ENTRENABLES: 46
# =======================================
# <ipython-input-38-85b55e55fcb3>:85: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
